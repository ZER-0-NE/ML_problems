# %% [markdown]
# ![image.png](attachment:fa238079-8f73-426d-b307-f919ce89d963.png)
#
# ![image.png](attachment:1792b5e4-4505-4985-906e-d1d8e8947f84.png)
#
# ![image.png](attachment:7f709533-c41b-4abf-bdfa-52a612e0202d.png)
#
# ![image.png](attachment:8c44b239-39c9-4b64-bf7b-6e0b26c4b1c9.png)
#
# ![image.png](attachment:3360a173-6e88-4427-a5da-74893a6b9b1a.png)
#
# ![image.png](attachment:04608d00-a2ea-4475-bbff-a406dcb93f97.png)
#
# ![image.png](attachment:1361e3bb-dcbd-4c81-b261-d30ad727356b.png)
#
# ![image.png](attachment:3b43ad17-aa9b-47e3-866c-ac91276a4e6b.png)
#
# ![image.png](attachment:b176f462-bb08-45cc-9286-f09281492ac8.png)
#
# ![image.png](attachment:a2bfdbc5-ce13-4232-bf21-c2504efc27b2.png)
#
# ![image.png](attachment:54431655-07c9-4176-9d73-16a556078199.png)
#
# ![image.png](attachment:b98463cf-e99f-4b75-9e54-634167774e7e.png)
#
# ![image.png](attachment:5bafb680-2e51-4757-b110-5c89aa10db5a.png)
#
# ![image.png](attachment:da90c653-4d33-45c1-a512-923e7b9d9a76.png)
#
# ![image.png](attachment:0aa52425-8778-4589-86be-deacab933911.png)
#
# ![image.png](attachment:67e54918-c461-4c68-9fd5-704f6eea7697.png)
#
# ![image.png](attachment:8a4270ed-9b8b-439c-a635-30aed1956cdb.png)
#
# ![image.png](attachment:4310c479-777c-4394-8747-21084ea01822.png)
#
# ![image.png](attachment:ca705193-d8b0-49dc-b71c-f1164fb4dab7.png)
#
# ![image.png](attachment:2d5e0843-48e6-4246-865a-0ff847f03320.png)
#
# ![image.png](attachment:7440be44-0f4d-4bf2-bf4a-5148500dc8d1.png)
#
# ![image.png](attachment:7c639c9f-318e-4ae9-971e-0a1df0264508.png)

# %% [markdown]
# ### REFERENCES:
#
# - https://tokens-for-thoughts.notion.site/post-training-101
