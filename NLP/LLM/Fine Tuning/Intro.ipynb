# %% [markdown]
# ![image.png](attachment:8cca7645-8f86-4277-b6c6-6f0346927f1d.png)
#
# ![image.png](attachment:602ca4b6-a0f5-4cca-8870-17e07ee07d77.png)
#
# ![image.png](attachment:6e6353ee-bdcb-4cd9-9004-cf490c369de0.png)
#
# ![image.png](attachment:7df233e5-ad96-4789-b297-075717e0b606.png)
#
# ![image.png](attachment:563eafe1-4231-4d94-9e9d-337370675258.png)
#
# ![image.png](attachment:113ce33f-713c-4148-b978-0f9913379e13.png)
#
# ![image.png](attachment:a2089bab-0346-4b76-9651-0c370c0a4791.png)
#
# ![image.png](attachment:905e83aa-2aae-4aa6-a27d-811fbe4be8be.png)

# %% [markdown]
# ### REFERENCES:
#
# - https://sebastianraschka.com/blog/2023/llm-finetuning-lora.html
# - https://aman.ai/primers/ai/parameter-efficient-fine-tuning/
