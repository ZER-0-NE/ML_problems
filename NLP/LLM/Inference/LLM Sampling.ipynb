# %% [markdown]
# ![image.png](attachment:2eeb3432-78c8-44e9-ade1-7127e5adb5e2.png)
#
# ![image.png](attachment:894d29e7-c84c-4421-a633-e479c78b3254.png)
#
# ![image.png](attachment:484591c1-96b9-46ed-ad8e-28c7186fdc37.png)

# %% [markdown]
# ### REFERENCES:
# - https://rentry.co/samplers
