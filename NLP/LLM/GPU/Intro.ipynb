# %% [markdown]
# - Single thread performance tapered out but moore's law kept on improving and we were able to have chips with higher density transistors. The paradigm changed to parallel computing/scaling(lot of workloads which are computed at once) rather than single threaded compute/scaling
#
# ![image.png](attachment:4af7caab-4495-4315-a06b-6eb60f701e36.png)
#
# ![image.png](attachment:636d7fab-8885-4c60-8286-d6473aa352e6.png)
#
# ![image.png](attachment:bd9e5066-17a9-45b6-bc07-0d1ff08b4092.png)
#
# ![image.png](attachment:bfb367fe-3c09-46ac-a0d0-6414df93117a.png)
#
# ![image.png](attachment:7cf55705-5ccf-4600-84e4-1a820d42629f.png)
#
# ![image.png](attachment:17a9a537-3f8c-43f4-bb1f-b991bed7cac1.png)
#
# ![image.png](attachment:5d3d4d81-a597-4467-9342-0cffe233a92b.png)
#
# ![image.png](attachment:ce6198a2-0c1e-456c-8419-39364dfacd9b.png)
